# %% [markdown]
# ***Question 1 (20 pts)***

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Using cached openpyxl-3.0.9-py2.py3-none-any.whl (242 kB)
# Collecting et-xmlfile
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.9
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

pathExcel = r'FirmAndExecutivesFinancialData.xlsx'

FinancialData = pd.read_excel(pathExcel)

# %%
FinancialData.columns
# Out:
# Index(['GVKEY', 'YEAR', 'Industry Format', 'TICKER', 'Company Name',
#        'Currency', 'Assets and Liabilities Due in 2 year', 'Assets – Total',
#        'Capital Surplus', 'Debt – Due in One Year', 'exchg', 'conml',
#        'EXEC_FULLNAME', 'CFOANN', 'CO_PER_ROL', 'TITLEANN', 'CEOANN', 'SALARY',
#        'BONUS', 'NONEQuity_INCENT', 'PENSION_CHG', 'Other Compensation',
#        'Total Compensation - As Reported in SEC',
#        'Total Current Compensation (Salary + Bonus',
#        'ALT 1 Total Compensation (fair value of stock/optio',
#        'TOTAL_ALT2 -- Total Compensation - Stock Valued at time of',
#        'Estimated Payments in event of involuntary te',
#        'Estimated Payments in event of change in cont', 'Shares Owned',
#        'SHROWN_TOT_PCT', 'Shares Owned - Options Excluded',
#        'SHROWN_EXCL_OPTS_PCT', 'umber of Shares Acquired on Option Exercise',
#        'Value Realized on Option Exercise',
#        'Number of Shares Acquired on Vesting', 'Value Realized on Vesting',
#        'AGE', 'Options Granted', 'Grant Date Fair Value of Options Granted ',
#        'STOCK_AWARDS_Fair Value', 'Unexercised Exercisable Options',
#        'Unexercised Exercisable Options.1',
#        'Estimated Value Of In-the-Money exercised',
#        'Estimated Value Of In-the-Money Unexercised',
#        'Restricted Stock Holdings', 'Restricted Stock Holdings Value',
#        'Equity Incentive Plan--Number of Unearned Share',
#        'Equity Incentive Plan - Value of Unearned',
#        'Present Value of Accumulated Pension Benefits',
#        'Total Payments Made From All Pension Plans',
#        'Executive Rank by Salary + Bonus', 'TDC1 Total Compensation',
#        'TDC2 Total compensation (Long-Term Incentive Payouts, and All Other Total)',
#        'Salary Percent Change', 'Compensation Percent Change',
#        'Total Compensation (SEC total) Percent Change', 'ALT1_PCT', 'ALT2_PCT',
#        'TDC1_PCT', 'TDC2_PCT', 'EXECID', 'PCEO', 'TITLE', 'EXEC_LNAME',
#        'EXEC_FNAME', 'EXEC_MNAME', 'GENDER', 'NAMEPREFIX', 'EXCHANGE',
#        'ADDRESS', 'CITY', 'STATE', 'ZIP', 'TELE', 'NAICSDESC', 'INDDESC',
#        'SPCODE', 'NAICS', 'SPINDEX', 'SIC'],
#       dtype='object')

# %% [markdown]
# 1.a) Return the number of rows with at least one missing value (2.5 pts)

# %%
# write code here
FinancialData.isna().any(axis=1).sum()
# Out:
# 52785

# %% [markdown]
# 1.b) Return the rows with at least one missing value (2.5 pts)

# %%
# write code here
FinancialData[FinancialData.isna().any(axis=1)]
# Out:
#         GVKEY  YEAR Industry Format TICKER    Company Name Currency  \
# 0        1004  2012            INDL    AIR        AAR CORP      USD
# 1        1004  2012            INDL    AIR        AAR CORP      USD
# 2        1004  2012            INDL    AIR        AAR CORP      USD
# 3        1004  2012            INDL    AIR        AAR CORP      USD
# 4        1004  2012            INDL    AIR        AAR CORP      USD
# ...       ...   ...             ...    ...             ...      ...
# 52809  317264  2014            INDL    LPG  DORIAN LPG LTD      USD
# 52810  317264  2014            INDL    LPG  DORIAN LPG LTD      USD
# 52811  317264  2015            INDL    LPG  DORIAN LPG LTD      USD
# 52812  317264  2015            INDL    LPG  DORIAN LPG LTD      USD
# 52813  317264  2015            INDL    LPG  DORIAN LPG LTD      USD
#
#        Assets and Liabilities Due in 2 year  Assets – Total  Capital Surplus  \
# 0                                       NaN        2136.900          431.600
# 1                                       NaN        2136.900          431.600
# 2                                       NaN        2136.900          431.600
# 3                                       NaN        2136.900          431.600
# 4                                       NaN        2136.900          431.600
# ...                                     ...             ...              ...
# 52809                                   NaN        1099.101          844.538
# 52810                                   NaN        1099.101          844.538
# 52811                                   0.0        1865.926          848.179
# 52812                                   0.0        1865.926          848.179
# 52813                                   0.0        1865.926          848.179
#
#        Debt – Due in One Year  ...  STATE    ZIP          TELE  \
# 0                      86.400  ...     IL  60191  630 227 2000
# 1                      86.400  ...     IL  60191  630 227 2000
# 2                      86.400  ...     IL  60191  630 227 2000
# 3                      86.400  ...     IL  60191  630 227 2000
# 4                      86.400  ...     IL  60191  630 227 2000
# ...                       ...  ...    ...    ...           ...
# 52809                  15.678  ...     CT   6902  203 674 9900
# 52810                  15.678  ...     CT   6902  203 674 9900
# 52811                  66.265  ...     CT   6902  203 674 9900
# 52812                  66.265  ...     CT   6902  203 674 9900
# 52813                  66.265  ...     CT   6902  203 674 9900
#
#                                             SICDESC  \
# 0      MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE
# 1      MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE
# 2      MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE
# 3      MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE
# 4      MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE
# ...                                             ...
# 52809    DEEP SEA FOREIGN TRANSPORTATION OF FREIGHT
# 52810    DEEP SEA FOREIGN TRANSPORTATION OF FREIGHT
# 52811    DEEP SEA FOREIGN TRANSPORTATION OF FREIGHT
# 52812    DEEP SEA FOREIGN TRANSPORTATION OF FREIGHT
# 52813    DEEP SEA FOREIGN TRANSPORTATION OF FREIGHT
#
#                                                NAICSDESC  \
# 0      Transportation Equipment and Supplies (except ...
# 1      Transportation Equipment and Supplies (except ...
# 2      Transportation Equipment and Supplies (except ...
# 3      Transportation Equipment and Supplies (except ...
# 4      Transportation Equipment and Supplies (except ...
# ...                                                  ...
# 52809                    Deep Sea Freight Transportation
# 52810                    Deep Sea Freight Transportation
# 52811                    Deep Sea Freight Transportation
# 52812                    Deep Sea Freight Transportation
# 52813                    Deep Sea Freight Transportation
#
#                                   INDDESC SPCODE   NAICS  SPINDEX   SIC
# 0                     Aerospace & Defense     EX  423860   2010.0  5080
# 1                     Aerospace & Defense     EX  423860   2010.0  5080
# 2                     Aerospace & Defense     EX  423860   2010.0  5080
# 3                     Aerospace & Defense     EX  423860   2010.0  5080
# 4                     Aerospace & Defense     EX  423860   2010.0  5080
# ...                                   ...    ...     ...      ...   ...
# 52809  Oil & Gas Storage & Transportation     EX  483111   1010.0  4412
# 52810  Oil & Gas Storage & Transportation     EX  483111   1010.0  4412
# 52811  Oil & Gas Storage & Transportation     EX  483111   1010.0  4412
# 52812  Oil & Gas Storage & Transportation     EX  483111   1010.0  4412
# 52813  Oil & Gas Storage & Transportation     EX  483111   1010.0  4412
#
# [52785 rows x 82 columns]

# %% [markdown]
# 1.c) Fill missing values of the columns "Assets – Total" and "Long-Term Debt – Total" with zero (5 pts)

# %%
# write code here
FinancialData.fillna({'Assets – Total':0,'Long-Term Debt – Total':0})
# Out:
#         GVKEY  YEAR Industry Format TICKER    Company Name Currency  \
# 0        1004  2012            INDL    AIR        AAR CORP      USD
# 1        1004  2012            INDL    AIR        AAR CORP      USD
# 2        1004  2012            INDL    AIR        AAR CORP      USD
# 3        1004  2012            INDL    AIR        AAR CORP      USD
# 4        1004  2012            INDL    AIR        AAR CORP      USD
# ...       ...   ...             ...    ...             ...      ...
# 52809  317264  2014            INDL    LPG  DORIAN LPG LTD      USD
# 52810  317264  2014            INDL    LPG  DORIAN LPG LTD      USD
# 52811  317264  2015            INDL    LPG  DORIAN LPG LTD      USD
# 52812  317264  2015            INDL    LPG  DORIAN LPG LTD      USD
# 52813  317264  2015            INDL    LPG  DORIAN LPG LTD      USD
#
#        Assets and Liabilities Due in 2 year  Assets – Total  Capital Surplus  \
# 0                                       NaN        2136.900          431.600
# 1                                       NaN        2136.900          431.600
# 2                                       NaN        2136.900          431.600
# 3                                       NaN        2136.900          431.600
# 4                                       NaN        2136.900          431.600
# ...                                     ...             ...              ...
# 52809                                   NaN        1099.101          844.538
# 52810                                   NaN        1099.101          844.538
# 52811                                   0.0        1865.926          848.179
# 52812                                   0.0        1865.926          848.179
# 52813                                   0.0        1865.926          848.179
#
#        Debt – Due in One Year  ...  STATE    ZIP          TELE  \
# 0                      86.400  ...     IL  60191  630 227 2000
# 1                      86.400  ...     IL  60191  630 227 2000
# 2                      86.400  ...     IL  60191  630 227 2000
# 3                      86.400  ...     IL  60191  630 227 2000
# 4                      86.400  ...     IL  60191  630 227 2000
# ...                       ...  ...    ...    ...           ...
# 52809                  15.678  ...     CT   6902  203 674 9900
# 52810                  15.678  ...     CT   6902  203 674 9900
# 52811                  66.265  ...     CT   6902  203 674 9900
# 52812                  66.265  ...     CT   6902  203 674 9900
# 52813                  66.265  ...     CT   6902  203 674 9900
#
#                                             SICDESC  \
# 0      MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE
# 1      MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE
# 2      MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE
# 3      MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE
# 4      MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE
# ...                                             ...
# 52809    DEEP SEA FOREIGN TRANSPORTATION OF FREIGHT
# 52810    DEEP SEA FOREIGN TRANSPORTATION OF FREIGHT
# 52811    DEEP SEA FOREIGN TRANSPORTATION OF FREIGHT
# 52812    DEEP SEA FOREIGN TRANSPORTATION OF FREIGHT
# 52813    DEEP SEA FOREIGN TRANSPORTATION OF FREIGHT
#
#                                                NAICSDESC  \
# 0      Transportation Equipment and Supplies (except ...
# 1      Transportation Equipment and Supplies (except ...
# 2      Transportation Equipment and Supplies (except ...
# 3      Transportation Equipment and Supplies (except ...
# 4      Transportation Equipment and Supplies (except ...
# ...                                                  ...
# 52809                    Deep Sea Freight Transportation
# 52810                    Deep Sea Freight Transportation
# 52811                    Deep Sea Freight Transportation
# 52812                    Deep Sea Freight Transportation
# 52813                    Deep Sea Freight Transportation
#
#                                   INDDESC SPCODE   NAICS  SPINDEX   SIC
# 0                     Aerospace & Defense     EX  423860   2010.0  5080
# 1                     Aerospace & Defense     EX  423860   2010.0  5080
# 2                     Aerospace & Defense     EX  423860   2010.0  5080
# 3                     Aerospace & Defense     EX  423860   2010.0  5080
# 4                     Aerospace & Defense     EX  423860   2010.0  5080
# ...                                   ...    ...     ...      ...   ...
# 52809  Oil & Gas Storage & Transportation     EX  483111   1010.0  4412
# 52810  Oil & Gas Storage & Transportation     EX  483111   1010.0  4412
# 52811  Oil & Gas Storage & Transportation     EX  483111   1010.0  4412
# 52812  Oil & Gas Storage & Transportation     EX  483111   1010.0  4412
# 52813  Oil & Gas Storage & Transportation     EX  483111   1010.0  4412
#
# [52814 rows x 82 columns]

# %% [markdown]
# 1.d) Calculate the mean and standard deviation of the column "Assets – Total" (2.5 pts)

# %%
# write code here
FinancialData['Assets – Total'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0        2136.900
# 1        2136.900
# 2        2136.900
# 3        2136.900
# 4        2136.900
#            ...
# 52809    1099.101
# 52810    1099.101
# 52811    1865.926
# 52812    1865.926
# 52813    1865.926
# Name: Assets – Total, Length: 52814, dtype: float64>

# %%
FinancialData['Assets – Total'].std
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of 0        2136.900
# 1        2136.900
# 2        2136.900
# 3        2136.900
# 4        2136.900
#            ...
# 52809    1099.101
# 52810    1099.101
# 52811    1865.926
# 52812    1865.926
# 52813    1865.926
# Name: Assets – Total, Length: 52814, dtype: float64>

# %% [markdown]
# 1.e) Return all the outliers based on the column "Assets – Total". We define an outlier = row that has a "Assets – Total" greater than (mean + 3 * standard deviation) (2.5 pts)

# %%
def find_outliers_IQR(FinancialDatat):
    q1=FinancialData.quantile(0.25)
    q3=FinancialData.quantile(.75)
    IQR=q3-q1
    outliers=FinancialData[((FinancialData<(3*IQR)))]
    return outliers

# %%
# write code here
outlier1=find_outliers_IQR(FinancialData['Assets – Total'])
print('The amount of outliers is: ' + str(len(outlier1)))
outlier1
# Out:
# <ipython-input-130-c3da3c46d48a>:5: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers=FinancialData[((FinancialData<(3*IQR)))]
# The amount of outliers is: 52814
#         GVKEY  YEAR Industry Format TICKER Company Name Currency  \
# 0        1004   NaN             NaN    NaN          NaN      NaN
# 1        1004   NaN             NaN    NaN          NaN      NaN
# 2        1004   NaN             NaN    NaN          NaN      NaN
# 3        1004   NaN             NaN    NaN          NaN      NaN
# 4        1004   NaN             NaN    NaN          NaN      NaN
# ...       ...   ...             ...    ...          ...      ...
# 52809  317264   NaN             NaN    NaN          NaN      NaN
# 52810  317264   NaN             NaN    NaN          NaN      NaN
# 52811  317264   NaN             NaN    NaN          NaN      NaN
# 52812  317264   NaN             NaN    NaN          NaN      NaN
# 52813  317264   NaN             NaN    NaN          NaN      NaN
#
#        Assets and Liabilities Due in 2 year  Assets – Total  Capital Surplus  \
# 0                                       NaN        2136.900          431.600
# 1                                       NaN        2136.900          431.600
# 2                                       NaN        2136.900          431.600
# 3                                       NaN        2136.900          431.600
# 4                                       NaN        2136.900          431.600
# ...                                     ...             ...              ...
# 52809                                   NaN        1099.101          844.538
# 52810                                   NaN        1099.101          844.538
# 52811                                   0.0        1865.926          848.179
# 52812                                   0.0        1865.926          848.179
# 52813                                   0.0        1865.926          848.179
#
#        Debt – Due in One Year  ...  STATE  ZIP TELE SICDESC NAICSDESC  \
# 0                      86.400  ...    NaN  NaN  NaN     NaN       NaN
# 1                      86.400  ...    NaN  NaN  NaN     NaN       NaN
# 2                      86.400  ...    NaN  NaN  NaN     NaN       NaN
# 3                      86.400  ...    NaN  NaN  NaN     NaN       NaN
# 4                      86.400  ...    NaN  NaN  NaN     NaN       NaN
# ...                       ...  ...    ...  ...  ...     ...       ...
# 52809                  15.678  ...    NaN  NaN  NaN     NaN       NaN
# 52810                  15.678  ...    NaN  NaN  NaN     NaN       NaN
# 52811                  66.265  ...    NaN  NaN  NaN     NaN       NaN
# 52812                  66.265  ...    NaN  NaN  NaN     NaN       NaN
# 52813                  66.265  ...    NaN  NaN  NaN     NaN       NaN
#
#        INDDESC SPCODE     NAICS  SPINDEX     SIC
# 0          NaN    NaN  423860.0   2010.0  5080.0
# 1          NaN    NaN  423860.0   2010.0  5080.0
# 2          NaN    NaN  423860.0   2010.0  5080.0
# 3          NaN    NaN  423860.0   2010.0  5080.0
# 4          NaN    NaN  423860.0   2010.0  5080.0
# ...        ...    ...       ...      ...     ...
# 52809      NaN    NaN  483111.0   1010.0  4412.0
# 52810      NaN    NaN  483111.0   1010.0  4412.0
# 52811      NaN    NaN  483111.0   1010.0  4412.0
# 52812      NaN    NaN  483111.0   1010.0  4412.0
# 52813      NaN    NaN  483111.0   1010.0  4412.0
#
# [52814 rows x 82 columns]

# %% [markdown]
# 1.f) Calculate the mean and standard deviation of the column "Long-Term Debt – Total" (2.5 pts)

# %%
# write code here
FinancialData['Long-Term Debt – Total'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0        622.200
# 1        622.200
# 2        622.200
# 3        622.200
# 4        622.200
#           ...
# 52809    184.666
# 52810    184.666
# 52811    770.103
# 52812    770.103
# 52813    770.103
# Name: Long-Term Debt – Total, Length: 52814, dtype: float64>

# %%
FinancialData['Long-Term Debt – Total'].std
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of 0        622.200
# 1        622.200
# 2        622.200
# 3        622.200
# 4        622.200
#           ...
# 52809    184.666
# 52810    184.666
# 52811    770.103
# 52812    770.103
# 52813    770.103
# Name: Long-Term Debt – Total, Length: 52814, dtype: float64>

# %% [markdown]
# 1.g) Return all the outliers based on the column "Long-Term Debt – Total". We define an outlier = row that has a "Long-Term Debt – Total" greater than (mean + 3 * standard deviation) (2.5 pts)

# %%
# write code here
outlier2=find_outliers_IQR(FinancialData['Long-Term Debt – Total'])
print('The number of outliers is: ' + str(len(outlier2)))
outlier2
# Out:
# <ipython-input-130-c3da3c46d48a>:5: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers=FinancialData[((FinancialData<(3*IQR)))]
# The number of outliers is: 52814
#         GVKEY  YEAR Industry Format TICKER Company Name Currency  \
# 0        1004   NaN             NaN    NaN          NaN      NaN
# 1        1004   NaN             NaN    NaN          NaN      NaN
# 2        1004   NaN             NaN    NaN          NaN      NaN
# 3        1004   NaN             NaN    NaN          NaN      NaN
# 4        1004   NaN             NaN    NaN          NaN      NaN
# ...       ...   ...             ...    ...          ...      ...
# 52809  317264   NaN             NaN    NaN          NaN      NaN
# 52810  317264   NaN             NaN    NaN          NaN      NaN
# 52811  317264   NaN             NaN    NaN          NaN      NaN
# 52812  317264   NaN             NaN    NaN          NaN      NaN
# 52813  317264   NaN             NaN    NaN          NaN      NaN
#
#        Assets and Liabilities Due in 2 year  Assets – Total  Capital Surplus  \
# 0                                       NaN        2136.900          431.600
# 1                                       NaN        2136.900          431.600
# 2                                       NaN        2136.900          431.600
# 3                                       NaN        2136.900          431.600
# 4                                       NaN        2136.900          431.600
# ...                                     ...             ...              ...
# 52809                                   NaN        1099.101          844.538
# 52810                                   NaN        1099.101          844.538
# 52811                                   0.0        1865.926          848.179
# 52812                                   0.0        1865.926          848.179
# 52813                                   0.0        1865.926          848.179
#
#        Debt – Due in One Year  ...  STATE  ZIP TELE SICDESC NAICSDESC  \
# 0                      86.400  ...    NaN  NaN  NaN     NaN       NaN
# 1                      86.400  ...    NaN  NaN  NaN     NaN       NaN
# 2                      86.400  ...    NaN  NaN  NaN     NaN       NaN
# 3                      86.400  ...    NaN  NaN  NaN     NaN       NaN
# 4                      86.400  ...    NaN  NaN  NaN     NaN       NaN
# ...                       ...  ...    ...  ...  ...     ...       ...
# 52809                  15.678  ...    NaN  NaN  NaN     NaN       NaN
# 52810                  15.678  ...    NaN  NaN  NaN     NaN       NaN
# 52811                  66.265  ...    NaN  NaN  NaN     NaN       NaN
# 52812                  66.265  ...    NaN  NaN  NaN     NaN       NaN
# 52813                  66.265  ...    NaN  NaN  NaN     NaN       NaN
#
#        INDDESC SPCODE     NAICS  SPINDEX     SIC
# 0          NaN    NaN  423860.0   2010.0  5080.0
# 1          NaN    NaN  423860.0   2010.0  5080.0
# 2          NaN    NaN  423860.0   2010.0  5080.0
# 3          NaN    NaN  423860.0   2010.0  5080.0
# 4          NaN    NaN  423860.0   2010.0  5080.0
# ...        ...    ...       ...      ...     ...
# 52809      NaN    NaN  483111.0   1010.0  4412.0
# 52810      NaN    NaN  483111.0   1010.0  4412.0
# 52811      NaN    NaN  483111.0   1010.0  4412.0
# 52812      NaN    NaN  483111.0   1010.0  4412.0
# 52813      NaN    NaN  483111.0   1010.0  4412.0
#
# [52814 rows x 82 columns]

# %% [markdown]
# ***Question 2 (40 pts)***

# %% [markdown]
# 2.a) Using FirmAndExecutivesFinancialData, calculate the average "Long-Term Debt – Total" per STATE (5 pts)
# * Which State has the highest average "Long-Term Debt - Total"? (2.5 pts)
# * Which State has the lowest average "Long-Term Debt – Total"? (2.5 pts)

# %%
FinancialData=FinancialData.set_index('STATE')
FinancialData.head(1)
# Out:
#        Long-Term Debt – Total  index  GVKEY  YEAR Industry Format TICKER  \
# STATE
# IL                      622.2      0   1004  2012            INDL    AIR
#
#       Company Name Currency  Assets and Liabilities Due in 2 year  \
# STATE
# IL        AAR CORP      USD                                   NaN
#
#        Assets – Total  ...       CITY    ZIP          TELE  \
# STATE                  ...
# IL             2136.9  ...  Wood Dale  60191  630 227 2000
#
#                                             SICDESC  \
# STATE
# IL     MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE
#
#                                                NAICSDESC              INDDESC  \
# STATE
# IL     Transportation Equipment and Supplies (except ...  Aerospace & Defense
#
#        SPCODE   NAICS SPINDEX   SIC
# STATE
# IL         EX  423860  2010.0  5080
#
# [1 rows x 82 columns]

# %%
# write code here
FinancialData.mean(level='STATE').sort_values(by=['Long-Term Debt – Total'],ascending=False)
#DC is not a state, but has the highest average long term debt, while Virginia has the highest average long term debt out of the real states
#While West Virginia having the lowest average long-term debt
# Out:
#        Long-Term Debt – Total         index          GVKEY         YEAR  \
# STATE
# DC              603695.218149  19619.798246   40207.767544  2013.521930
# VA               53089.595115  29232.217758   67612.606610  2013.487362
# DE               26649.637302  14407.126984   12381.338624  2013.629630
# NY               11656.942128  25766.153448   58919.977155  2013.476293
# NC               11257.310930  23061.278134   43793.968893  2013.482159
# NE                8968.663860  27146.235808   64491.296943  2013.532751
# ON                6804.898236  27249.833333   86398.375000  2013.527778
# KS                4910.797255  28640.844106   62804.988593  2013.581749
# RI                4899.508008  18678.686441   21324.601695  2013.576271
# AR                4444.148291  24684.700000   50962.917143  2013.562857
# MA                4158.488430  29543.489231   65469.127033  2013.483516
# MI                3523.343661  22713.626437   37572.211686  2013.442529
# LA                3469.841025  27640.860317   61380.952381  2013.492063
# IN                3455.857455  27748.835897   62985.426923  2013.511538
# NV                3433.243111  30305.732530   74789.920482  2013.440964
# IL                3043.117472  26371.966602   62437.131971  2013.490921
# MN                2951.621026  20375.974205   41214.686156  2013.485813
# CT                2830.429625  24304.319263   51829.411358  2013.473523
# IA                2825.682215  25053.664430   62641.154362  2013.546980
# OK                2804.042604  26297.897216   50857.509636  2013.492505
# NJ                2798.042530  27529.994872   72754.340385  2013.450641
# PA                2758.210638  22717.031109   39557.862489  2013.477006
# OH                2728.183224  16175.648718   22861.822051  2013.505641
# GA                2706.178778  23512.504442   46773.706218  2013.490482
# TN                2617.785071  25314.236111   47302.724359  2013.513889
# CA                2505.100510  30554.039240   73899.316811  2013.455459
# TX                2410.652156  27264.784236   61992.633371  2013.469150
# WA                2239.221915  28158.992933   58371.637220  2013.446408
# CO                1991.366700  30752.106719   76370.314625  2013.510672
# MO                1896.216745  21971.438557   45100.443067  2013.446449
# NM                1737.293250  12206.500000    8807.000000  2013.500000
# FL                1607.480871  29691.337188   71190.813599  2013.510176
# KY                1438.962076  27032.009063   55141.069486  2013.534743
# AZ                1375.699443  27006.388889   56100.227124  2013.462418
# MD                1362.139012  31737.637838   79163.400000  2013.455135
# ID                1323.049837  15116.595745   28099.368794  2013.425532
# PR                1276.795834  21020.036810   38899.601227  2013.509202
# ND                1260.905585  27552.538462   44843.400000  2013.461538
# AL                1235.021412  25891.961340   48588.394330  2013.394330
# WI                1231.821552  18350.726592   26736.077403  2013.503121
# SC                 894.122502  25712.311966   56667.538462  2013.534188
# BC                 782.760957  20112.000000   14563.000000  2013.521739
# OR                 780.316371  25794.525701   41518.850467  2013.471963
# UT                 735.249736  24078.070225   42734.120787  2013.522472
# WY                 598.366435  50092.000000  180635.000000  2013.478261
# QC                 579.619048   2014.000000    2337.000000  2013.476190
# HI                 576.031505  13674.729167   15222.562500  2013.572917
# ME                 521.516985  39380.000000  117677.117647  2013.397059
# SD                 473.410758  20339.143791   18296.183007  2013.653595
# MT                 373.571769  21684.500000   16832.000000  2013.615385
# MS                 299.661916  18771.116788   18596.591241  2013.478102
# NH                 153.173576  29082.141176   63845.776471  2013.435294
# WV                 138.528855  27515.572727   49387.981818  2013.481818
#
#        Assets and Liabilities Due in 2 year  Assets – Total  Capital Surplus  \
# STATE
# DC                              8675.556563   632301.670759      1191.289083
# VA                              6122.802183    75996.538107      2881.484339
# DE                              1146.732907    45939.108022      3036.636532
# NY                             38337.085691    90699.703033      7671.151628
# NC                             39622.783401   100802.352849      8383.035170
# NE                              1793.919250    64355.179712      4730.687948
# ON                               181.786556    18567.692278       559.426778
# KS                               163.336031    13158.315373      5109.375876
# RI                              5776.222155    56022.217331     11188.201356
# AR                               193.733883    20543.396583       789.453435
# MA                              2337.362384    18396.003891      2060.251519
# MI                               981.462964    13939.141362      1727.685807
# LA                               866.269641    11425.451454      2336.346698
# IN                              2418.986258    12167.902969      2420.391491
# NV                               340.425068     6764.006740      1435.411720
# IL                              2100.689163    15691.181301      2411.861312
# MN                              4387.151703    26960.184530      1200.112376
# CT                              4996.089191    22312.340277      1739.790053
# IA                             15759.021967    40620.416809      1949.881245
# OK                               282.852497     9218.753600      2215.608889
# NJ                             13477.977112    30132.593451      2501.874474
# PA                              4167.963991    18975.378387      1941.698207
# OH                              1907.876135    17364.732987      2596.025907
# GA                              2340.794632    18381.246525      2057.272807
# TN                              1861.177730     9851.428641      1193.947726
# CA                              3733.669978    20450.169973      2923.842284
# TX                               484.701393    11371.893819      2242.414657
# WA                              1190.127527    12042.714919      3793.160876
# CO                               226.434877     5440.219454      1968.073131
# MO                              1394.947585    10871.359657      1965.241219
# NM                                77.722000     5677.861500         0.000000
# FL                               636.005911     6387.162856      1215.239405
# KY                               816.586794     6165.737055       690.857395
# AZ                               234.419399     5433.770457      1755.346189
# MD                               187.075259     4910.525323      2077.569643
# ID                               511.314029     5607.360333      2057.777109
# PR                              2134.689628    15410.784583      1515.376577
# ND                                95.768696     3701.604846       400.169631
# AL                              4038.933104    18894.347015      2703.846423
# WI                               420.767272     5448.988583       828.920414
# SC                                68.500309     3350.516792       503.501353
# BC                                 0.213478     1404.199261       297.525217
# OR                               957.421142     7513.516234       438.245914
# UT                               443.750283     8933.806365       397.654411
# WY                                56.215348     2168.045130       563.029478
# QC                                      NaN     5220.714286      3750.047619
# HI                              1107.381317     7685.996651       222.326300
# ME                                31.759267     2838.740574       392.991632
# SD                               429.771232     3356.986941       499.071216
# MT                              2948.347231     8320.909154       697.577308
# MS                              1334.317378     8953.119500       600.702953
# NH                                 0.210597      773.970082       263.369035
# WV                               623.532455     5798.462855       277.793800
#
#        Debt – Due in One Year      exchg    CO_PER_ROL  ...  \
# STATE                                                   ...
# DC                 132.863897  13.070175  47623.258772  ...
# VA                2732.970507  12.329229  42483.515878  ...
# DE                3502.553429  12.825397  46653.682540  ...
# NY                1900.841667  11.779741  40458.782543  ...
# NC                1983.947217  11.753888  41178.703568  ...
# NE                 883.061906  12.205240  35021.144105  ...
# ON                 250.964542  11.000000  40029.888889  ...
# KS                 386.562708  11.965779  45387.102662  ...
# RI                 194.684831  11.635593  42727.355932  ...
# AR                 447.095237  13.205714  39107.777143  ...
# MA                1035.411844  12.659780  41676.428132  ...
# MI                 786.574720  12.287356  42530.821839  ...
# LA                 160.156654  14.006349  39670.873016  ...
# IN                 249.478663  12.520513  40685.435897  ...
# NV                 320.094098  12.409639  43197.665060  ...
# IL                 435.299916  12.267510  41721.254864  ...
# MN                 343.407324  12.604471  40955.186586  ...
# CT                 318.932878  12.050652  41766.204912  ...
# IA                  90.288641  11.761745  38182.335570  ...
# OK                 123.421669  12.623126  43583.316916  ...
# NJ                 214.407635  12.257051  42266.139744  ...
# PA                 124.333202  11.923354  41983.468891  ...
# OH                 284.847019  11.785128  39571.551795  ...
# GA                 193.249161  11.655457  41188.691624  ...
# TN                 119.357490  12.432692  41595.216880  ...
# CA                 257.841979  12.829822  42968.299188  ...
# TX                 147.437375  12.401053  43323.873025  ...
# WA                 217.035431  12.944641  40853.106007  ...
# CO                 127.766676  12.161576  44692.271937  ...
# MO                 202.757945  12.156708  38394.385569  ...
# NM                 133.893750  11.000000  41213.800000  ...
# FL                 174.415428  12.075856  43264.895930  ...
# KY                  61.292762  11.734139  42116.404834  ...
# AZ                  82.948799  12.661765  42842.897059  ...
# MD                  91.985453  12.245405  43149.395676  ...
# ID                 226.655035  12.723404  40656.070922  ...
# PR                 168.207362  11.773006  43022.717791  ...
# ND                 112.241709  11.000000  55919.492308  ...
# AL                 121.316211  12.182990  37462.646907  ...
# WI                  74.753970  11.820225  38129.891386  ...
# SC                  25.972973  12.333333  41937.692308  ...
# BC                  35.104130  14.000000  61139.260870  ...
# OR                  58.971781  12.177570  40238.028037  ...
# UT                  54.662075  12.483146  40049.561798  ...
# WY                  46.327913  19.000000  45323.347826  ...
# QC                   1.523810  11.000000  45715.714286  ...
# HI                  35.029576  11.531250  44099.505208  ...
# ME                  12.966838  11.970588  40257.808824  ...
# SD                  20.796131  13.098039  47309.869281  ...
# MT                 373.811769  14.000000  34791.692308  ...
# MS                  18.352670  13.215328  43586.989051  ...
# NH                   9.635268  13.188235  44151.988235  ...
# WV                 194.697764  14.000000  36862.663636  ...
#
#        Compensation Percent Change  \
# STATE
# DC                       15.910364
# VA                       14.811465
# DE                       12.961308
# NY                       13.975415
# NC                        8.367084
# NE                        5.938795
# ON                       50.411661
# KS                       13.183390
# RI                       -0.881731
# AR                       10.369960
# MA                       10.925746
# MI                        9.915544
# LA                        4.424122
# IN                        9.428660
# NV                       14.277059
# IL                       15.058919
# MN                       16.522915
# CT                        9.288691
# IA                        7.103457
# OK                        9.083920
# NJ                       14.738671
# PA                       16.334715
# OH                        6.954448
# GA                       14.431319
# TN                       17.509645
# CA                       20.469758
# TX                       19.317637
# WA                        9.651297
# CO                       13.371515
# MO                        7.151127
# NM                       -0.299611
# FL                       17.200433
# KY                       18.573538
# AZ                       16.011233
# MD                        8.301517
# ID                       12.212172
# PR                        3.585442
# ND                       -0.428714
# AL                        5.431949
# WI                       11.395182
# SC                       21.115184
# BC                       11.477905
# OR                       10.759730
# UT                        9.681024
# WY                       -1.900909
# QC                       12.616353
# HI                        4.513380
# ME                        2.252655
# SD                        8.679144
# MT                       12.358250
# MS                       12.792577
# NH                       15.710536
# WV                        7.929396
#
#        Total Compensation (SEC total) Percent Change   ALT1_PCT    ALT2_PCT  \
# STATE
# DC                                         44.434837  48.254179   44.135581
# VA                                         62.163017  66.730409   75.832176
# DE                                         13.688513  25.436211   68.700908
# NY                                         30.206651  33.553272   43.336475
# NC                                         17.372433  15.639050   46.202522
# NE                                         18.452681  10.797775   20.262135
# ON                                         30.979508  22.667811   45.234509
# KS                                         84.151064  62.502201   25.239657
# RI                                         14.090000  18.465624   38.232495
# AR                                         24.566545  17.566156   28.308567
# MA                                         30.309308  29.528772   49.680564
# MI                                         22.157419  22.208673   68.186967
# LA                                         13.171162  14.204751   29.753189
# IN                                         13.207138  14.060470   34.354984
# NV                                         28.850159  24.464976   57.314869
# IL                                         64.766088  23.666380  103.468640
# MN                                         16.746502  17.717200   53.101327
# CT                                        116.850236  19.218062   49.209042
# IA                                         15.088301  12.487177   23.283200
# OK                                         26.464222  22.859043   53.876012
# NJ                                         66.177196  30.927645   47.659857
# PA                                         15.909530  18.699869   43.776709
# OH                                         20.665366  18.247319   41.343992
# GA                                         30.608626  33.979207   44.684877
# TN                                         21.142380  24.868260   64.940379
# CA                                         87.934006  94.644118  143.490882
# TX                                         65.673175  68.366290   58.544409
# WA                                         78.494697  89.770845   39.097818
# CO                                         28.650979  24.507160   53.964225
# MO                                         20.274064  22.973217   56.316987
# NM                                          4.528056   4.528056   19.159222
# FL                                         36.313243  32.558168   56.230372
# KY                                         28.959444  29.718269  149.194147
# AZ                                         30.247428  28.178751   50.532319
# MD                                         18.375931  24.356137   44.773831
# ID                                         23.437615  22.533070   39.870123
# PR                                         15.995145  19.817739   52.710504
# ND                                         19.793304  16.226922   -1.815529
# AL                                         11.007212   8.111339   31.884419
# WI                                         12.705714  12.325167   40.887794
# SC                                         36.963010  10.840665   65.638911
# BC                                         -1.127905  15.725053   -1.789947
# OR                                         17.886962  19.390922   38.625116
# UT                                         26.446784  22.170509   43.333193
# WY                                          4.488091   4.339619   35.711095
# QC                                         12.813824  39.132118   24.842235
# HI                                         14.634221  13.434514   26.997051
# ME                                         16.879534  10.159529   19.971569
# SD                                         16.237592  14.784759   15.950045
# MT                                         36.131417  28.933917   37.940500
# MS                                         21.383280  10.548754   29.611746
# NH                                         12.652667  14.843692   29.561923
# WV                                          4.991030   4.989527   22.053176
#
#         TDC1_PCT    TDC2_PCT        EXECID          NAICS      SPINDEX  \
# STATE
# DC     47.447397   52.474553  42977.219298  410357.333333  4533.815789
# VA     67.495614   73.954493  37042.399870  458592.066105  3664.918989
# DE     27.496951   66.586725  41749.698413  279960.539683  3461.904762
# NY     33.795344   50.645597  36390.542026  465211.199138  3919.318966
# NC     16.242607   38.086892  36615.129918  384404.683440  3294.940531
# NE     10.496910   11.397994  32096.659389  494162.082969  2620.917031
# ON     22.504509   40.870472  36500.569444  479913.972222  1984.583333
# KS     65.790833   48.124529  41529.927757  494116.357414  3593.764259
# RI     20.090333   32.190398  37219.737288  427332.601695  3151.949153
# AR     20.491640   31.642022  36778.051429  442093.482857  3188.942857
# MA     30.203727   51.004311  37347.044396  421288.112527  3900.589011
# MI     23.496616   42.796336  38884.937739  358277.437739  3304.176245
# LA     12.426524   21.900638  36852.079365  388328.473016  3682.952381
# IN     14.550728   29.208249  36578.966667  414367.330769  3548.141026
# NV     24.026878   42.252988  37745.308434  532856.814458  3174.530120
# IL     24.324676   47.299370  37283.252594  418174.572633  3440.288586
# MN     17.096336   37.112151  36789.533104  387422.411006  2988.830610
# CT     19.372366   33.292454  36989.774367  431485.544896  3459.869532
# IA     12.422340   21.501238  36033.771812  436596.073826  3577.516779
# OK     21.895197   22.103783  39683.888651  272158.434690  2464.218415
# NJ     31.033449   39.319741  38125.667949  411534.939103  3715.852564
# PA     18.676906   34.999090  37436.748873  412477.805230  3414.864743
# OH     18.662625   26.157766  35894.586667  402168.037949  3082.184615
# GA     34.711161   41.843602  36738.354695  418042.355330  3450.977157
# TN     27.364415   47.450359  36511.121795  509474.772436  3410.213675
# CA     94.717177  120.133321  37959.296985  416407.404103  4043.090058
# TX     69.709565   52.135461  38805.496050  373544.119074  2822.473664
# WA     87.930895   73.904933  36390.868080  417545.612485  3596.383981
# CO     24.713651   75.467765  39847.123320  398835.412648  3457.936759
# MO     23.987598   42.556067  34506.313416  369273.423901  3364.284104
# NM      4.528056    6.061556  38797.600000    2211.000000  5510.000000
# FL     32.861918   43.190093  38056.366327  473487.679001  3612.178538
# KY     30.009143   50.416563  37107.643505  493804.758308  2905.347432
# AZ     28.746566   46.309755  37189.040850  411069.635621  3315.163399
# MD     25.686681   41.751387  39618.988108  464720.435676  4310.951351
# ID     26.330412   35.786474  36429.432624  328558.184397  3169.929078
# PR     21.621304   50.543296  39500.717791  521511.840491  4086.687117
# ND     17.730569   17.730569  51556.153846  421504.769231  5833.076923
# AL      8.493242   35.389488  34937.347938  478923.979381  3557.603093
# WI     12.933428   25.426109  34321.857678  360017.188514  3036.941323
# SC     10.358520   23.360877  38212.230769  373885.371795  3631.794872
# BC     15.971158   15.971158  56005.260870  322110.000000  1510.000000
# OR     19.588575   29.123604  36475.313084  363562.439252  3843.060748
# UT     22.317089   43.577416  37023.106742  416479.370787  3611.685393
# WY      4.339619   11.263238  41643.695652  212111.000000  1010.000000
# QC     41.996529   37.483647  42999.190476  322121.000000  1510.000000
# HI     14.519109   24.736804  38298.880208  404132.562500  3920.937500
# ME     10.269490    5.157588  37140.147059  455834.500000  4186.470588
# SD     14.650000   16.907768  43720.111111  330574.019608  4148.692810
# MT     26.777417   27.752083  33178.153846  522110.000000  4010.000000
# MS     12.315408   14.008149  39748.529197  474743.740876  4131.642336
# NH     14.037415   14.145046  41421.800000  382398.717647  3249.882353
# WV      6.204692   19.648978  34643.327273  539950.000000  3714.000000
#
#                SIC
# STATE
# DC     5696.149123
# VA     5551.543746
# DE     4745.566138
# NY     5560.531466
# NC     4778.174748
# NE     5209.755459
# ON     3748.097222
# KS     5286.076046
# RI     5081.754237
# AR     4821.582857
# MA     5182.570110
# MI     4623.330460
# LA     5341.752381
# IN     5156.079487
# NV     6124.600000
# IL     4936.798314
# MN     4617.829751
# CT     5270.612433
# IA     4795.036913
# OK     3763.980728
# NJ     4973.379487
# PA     5143.338593
# OH     4612.613846
# GA     5253.087563
# TN     5919.757479
# CA     5089.103676
# TX     4414.088977
# WA     5059.361602
# CO     4367.162055
# MO     4691.395716
# NM     4911.000000
# FL     5591.095745
# KY     5156.897281
# AZ     5103.903595
# MD     5472.904865
# ID     3994.801418
# PR     6227.668712
# ND     6137.723077
# AL     5942.087629
# WI     4615.193508
# SC     4640.598291
# BC     2611.000000
# OR     4676.560748
# UT     4875.132022
# WY     1220.000000
# QC     2621.000000
# HI     5622.718750
# ME     5905.500000
# SD     4964.313725
# MT     6020.000000
# MS     5425.937956
# NH     4331.764706
# WV     6456.000000
#
# [53 rows x 57 columns]

# %%
FinancialData.reset_index()
FinancialData.head(1)
# Out:
#    GVKEY  YEAR Industry Format TICKER Company Name Currency  \
# 0   1004  2012            INDL    AIR     AAR CORP      USD
#
#    Assets and Liabilities Due in 2 year  Assets – Total  Capital Surplus  \
# 0                                   NaN          2136.9            431.6
#
#    Debt – Due in One Year  ...  STATE    ZIP          TELE  \
# 0                    86.4  ...     IL  60191  630 227 2000
#
#                                         SICDESC  \
# 0  MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE
#
#                                            NAICSDESC              INDDESC  \
# 0  Transportation Equipment and Supplies (except ...  Aerospace & Defense
#
#   SPCODE   NAICS  SPINDEX   SIC
# 0     EX  423860   2010.0  5080
#
# [1 rows x 82 columns]

# %%
FinancialData=FinancialData.set_index('SICDESC')
FinancialData.head(1)
# Out:
#                                               GVKEY  YEAR Industry Format  \
# SICDESC
# MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE   1004  2012            INDL
#
#                                              TICKER Company Name Currency  \
# SICDESC
# MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE    AIR     AAR CORP      USD
#
#                                               Assets and Liabilities Due in 2 year  \
# SICDESC
# MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE                                   NaN
#
#                                               Assets – Total  Capital Surplus  \
# SICDESC
# MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE          2136.9            431.6
#
#                                               Debt – Due in One Year  ...  \
# SICDESC                                                               ...
# MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE                    86.4  ...
#
#                                                    CITY  STATE    ZIP  \
# SICDESC
# MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE  Wood Dale     IL  60191
#
#                                                       TELE  \
# SICDESC
# MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE  630 227 2000
#
#                                                                                       NAICSDESC  \
# SICDESC
# MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE  Transportation Equipment and Supplies (except ...
#
#                                                           INDDESC SPCODE  \
# SICDESC
# MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE  Aerospace & Defense     EX
#
#                                                NAICS  SPINDEX   SIC
# SICDESC
# MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE  423860   2010.0  5080
#
# [1 rows x 81 columns]

# %% [markdown]
# 2.b) Using FirmAndExecutivesFinancialData, calculate the average "Long-Term Debt – Total" per Industry (5 pts)
# * NAICS or SIC represent industries. You can use either of the two.
# * Which Industry has the highest average "Long-Term Debt – Total"? (2.5 pts)
# * Which Industry has the lowest average "Long-Term Debt – Total"? (2.5 pts)

# %%
# write code here
FinancialData.mean(level='SICDESC').sort_values(by=['Long-Term Debt – Total'],ascending=False)
#Federal Credit agencies have the highest average long term debt, while Coating services have the lowest average long term debt
# Out:
#                                                          GVKEY         YEAR  \
# SICDESC
# FEDERAL AND FEDERALLY-SPONSORED CREDIT AGENCIES    9964.836066  2013.459016
# CONGLOMERATES                                      2810.772727  2013.500000
# FINANCE SERVICES                                  85003.638298  2013.404255
# BEVERAGES                                          8479.000000  2013.500000
# SECURITY BROKERS, DEALERS, & FLOTATION COMPANIES  68961.172775  2013.441536
# ...                                                        ...          ...
# DRAWING AND INSULATING OF NONFERROUS WIRE         25572.000000  2013.500000
# PENS, PENCILS, AND OTHER ARTISTS' MATERIALS        3612.000000  2012.000000
# POWER, DISTRIBUTION, AND SPECIALTY TRANSFORMERS   12581.000000  2013.000000
# COMPUTER PROGRAMMING SERVICES                      1634.000000  2012.000000
# COATING, ENGRAVING, AND ALLIED SERVICES            7107.000000  2012.000000
#
#                                                   Assets and Liabilities Due in 2 year  \
# SICDESC
# FEDERAL AND FEDERALLY-SPONSORED CREDIT AGENCIES                           64776.606557
# CONGLOMERATES                                                             20052.407407
# FINANCE SERVICES                                                         622144.845681
# BEVERAGES                                                                  3063.909091
# SECURITY BROKERS, DEALERS, & FLOTATION COMPANIES                          55327.659695
# ...                                                                                ...
# DRAWING AND INSULATING OF NONFERROUS WIRE                                          NaN
# PENS, PENCILS, AND OTHER ARTISTS' MATERIALS                                   0.257000
# POWER, DISTRIBUTION, AND SPECIALTY TRANSFORMERS                                    NaN
# COMPUTER PROGRAMMING SERVICES                                                      NaN
# COATING, ENGRAVING, AND ALLIED SERVICES                                            NaN
#
#                                                   Assets – Total  \
# SICDESC
# FEDERAL AND FEDERALLY-SPONSORED CREDIT AGENCIES     1.923250e+06
# CONGLOMERATES                                       3.935134e+05
# FINANCE SERVICES                                    8.628577e+05
# BEVERAGES                                           7.298932e+04
# SECURITY BROKERS, DEALERS, & FLOTATION COMPANIES    1.459053e+05
# ...                                                          ...
# DRAWING AND INSULATING OF NONFERROUS WIRE           5.497900e+02
# PENS, PENCILS, AND OTHER ARTISTS' MATERIALS         1.613390e+02
# POWER, DISTRIBUTION, AND SPECIALTY TRANSFORMERS     8.649467e+01
# COMPUTER PROGRAMMING SERVICES                       2.471900e+01
# COATING, ENGRAVING, AND ALLIED SERVICES             1.271060e+02
#
#                                                   Capital Surplus  \
# SICDESC
# FEDERAL AND FEDERALLY-SPONSORED CREDIT AGENCIES        999.295082
# CONGLOMERATES                                        25431.924242
# FINANCE SERVICES                                     51006.636511
# BEVERAGES                                             4117.000000
# SECURITY BROKERS, DEALERS, & FLOTATION COMPANIES      7511.394091
# ...                                                           ...
# DRAWING AND INSULATING OF NONFERROUS WIRE               50.344750
# PENS, PENCILS, AND OTHER ARTISTS' MATERIALS             32.309000
# POWER, DISTRIBUTION, AND SPECIALTY TRANSFORMERS        144.988000
# COMPUTER PROGRAMMING SERVICES                           26.644000
# COATING, ENGRAVING, AND ALLIED SERVICES                 81.089000
#
#                                                   Debt – Due in One Year  \
# SICDESC
# FEDERAL AND FEDERALLY-SPONSORED CREDIT AGENCIES             51639.435897
# CONGLOMERATES                                               26170.681818
# FINANCE SERVICES                                            31741.337500
# BEVERAGES                                                    3075.454545
# SECURITY BROKERS, DEALERS, & FLOTATION COMPANIES             5334.048221
# ...                                                                  ...
# DRAWING AND INSULATING OF NONFERROUS WIRE                       0.000000
# PENS, PENCILS, AND OTHER ARTISTS' MATERIALS                    15.000000
# POWER, DISTRIBUTION, AND SPECIALTY TRANSFORMERS                 0.000000
# COMPUTER PROGRAMMING SERVICES                                   0.000000
# COATING, ENGRAVING, AND ALLIED SERVICES                         0.000000
#
#                                                   Long-Term Debt – Total  \
# SICDESC
# FEDERAL AND FEDERALLY-SPONSORED CREDIT AGENCIES             1.788749e+06
# CONGLOMERATES                                               1.012392e+05
# FINANCE SERVICES                                            8.552841e+04
# BEVERAGES                                                   2.533236e+04
# SECURITY BROKERS, DEALERS, & FLOTATION COMPANIES            2.443371e+04
# ...                                                                  ...
# DRAWING AND INSULATING OF NONFERROUS WIRE                   0.000000e+00
# PENS, PENCILS, AND OTHER ARTISTS' MATERIALS                 0.000000e+00
# POWER, DISTRIBUTION, AND SPECIALTY TRANSFORMERS             0.000000e+00
# COMPUTER PROGRAMMING SERVICES                               0.000000e+00
# COATING, ENGRAVING, AND ALLIED SERVICES                     0.000000e+00
#
#                                                       exchg    CO_PER_ROL  \
# SICDESC
# FEDERAL AND FEDERALLY-SPONSORED CREDIT AGENCIES   17.606557  44635.475410
# CONGLOMERATES                                     11.000000  23533.060606
# FINANCE SERVICES                                  11.000000  54160.170213
# BEVERAGES                                         14.000000  40655.090909
# SECURITY BROKERS, DEALERS, & FLOTATION COMPANIES  12.232112  40701.082024
# ...                                                     ...           ...
# DRAWING AND INSULATING OF NONFERROUS WIRE         14.000000  38570.500000
# PENS, PENCILS, AND OTHER ARTISTS' MATERIALS       14.000000  27890.400000
# POWER, DISTRIBUTION, AND SPECIALTY TRANSFORMERS   14.000000  38737.000000
# COMPUTER PROGRAMMING SERVICES                     14.000000  45214.333333
# COATING, ENGRAVING, AND ALLIED SERVICES           14.000000  37349.000000
#
#                                                        SALARY  ...  \
# SICDESC                                                        ...
# FEDERAL AND FEDERALLY-SPONSORED CREDIT AGENCIES   1219.205443  ...
# CONGLOMERATES                                     1210.054000  ...
# FINANCE SERVICES                                   619.742681  ...
# BEVERAGES                                          942.912636  ...
# SECURITY BROKERS, DEALERS, & FLOTATION COMPANIES   690.667218  ...
# ...                                                       ...  ...
# DRAWING AND INSULATING OF NONFERROUS WIRE          527.500000  ...
# PENS, PENCILS, AND OTHER ARTISTS' MATERIALS        369.561400  ...
# POWER, DISTRIBUTION, AND SPECIALTY TRANSFORMERS    254.333133  ...
# COMPUTER PROGRAMMING SERVICES                      188.333333  ...
# COATING, ENGRAVING, AND ALLIED SERVICES            321.500000  ...
#
#                                                   TDC2 Total compensation (Long-Term Incentive Payouts, and All Other Total)  \
# SICDESC
# FEDERAL AND FEDERALLY-SPONSORED CREDIT AGENCIES                                         2262.910661
# CONGLOMERATES                                                                          12105.101321
# FINANCE SERVICES                                                                        7013.132634
# BEVERAGES                                                                              11461.543950
# SECURITY BROKERS, DEALERS, & FLOTATION COMPANIES                                        7274.148753
# ...                                                                                             ...
# DRAWING AND INSULATING OF NONFERROUS WIRE                                               1086.184750
# PENS, PENCILS, AND OTHER ARTISTS' MATERIALS                                             1352.735800
# POWER, DISTRIBUTION, AND SPECIALTY TRANSFORMERS                                          493.547933
# COMPUTER PROGRAMMING SERVICES                                                            252.330667
# COATING, ENGRAVING, AND ALLIED SERVICES                                                  650.499667
#
#                                                   Salary Percent Change  \
# SICDESC
# FEDERAL AND FEDERALLY-SPONSORED CREDIT AGENCIES               27.293980
# CONGLOMERATES                                                  3.178935
# FINANCE SERVICES                                             131.818472
# BEVERAGES                                                      4.716467
# SECURITY BROKERS, DEALERS, & FLOTATION COMPANIES               8.919268
# ...                                                                 ...
# DRAWING AND INSULATING OF NONFERROUS WIRE                      5.461875
# PENS, PENCILS, AND OTHER ARTISTS' MATERIALS                    1.620000
# POWER, DISTRIBUTION, AND SPECIALTY TRANSFORMERS               37.541667
# COMPUTER PROGRAMMING SERVICES                                 12.643000
# COATING, ENGRAVING, AND ALLIED SERVICES                       -0.485333
#
#                                                   Compensation Percent Change  \
# SICDESC
# FEDERAL AND FEDERALLY-SPONSORED CREDIT AGENCIES                     17.512959
# CONGLOMERATES                                                        4.075371
# FINANCE SERVICES                                                    15.711417
# BEVERAGES                                                           -1.678200
# SECURITY BROKERS, DEALERS, & FLOTATION COMPANIES                    16.985833
# ...                                                                       ...
# DRAWING AND INSULATING OF NONFERROUS WIRE                            5.754250
# PENS, PENCILS, AND OTHER ARTISTS' MATERIALS                          6.416800
# POWER, DISTRIBUTION, AND SPECIALTY TRANSFORMERS                     37.541667
# COMPUTER PROGRAMMING SERVICES                                       12.643000
# COATING, ENGRAVING, AND ALLIED SERVICES                             -0.485333
#
#                                                   Total Compensation (SEC total) Percent Change  \
# SICDESC
# FEDERAL AND FEDERALLY-SPONSORED CREDIT AGENCIES                                       17.381980
# CONGLOMERATES                                                                          4.941677
# FINANCE SERVICES                                                                      11.931167
# BEVERAGES                                                                             14.525667
# SECURITY BROKERS, DEALERS, & FLOTATION COMPANIES                                      55.730958
# ...                                                                                         ...
# DRAWING AND INSULATING OF NONFERROUS WIRE                                              9.351625
# PENS, PENCILS, AND OTHER ARTISTS' MATERIALS                                            6.583400
# POWER, DISTRIBUTION, AND SPECIALTY TRANSFORMERS                                       34.927467
# COMPUTER PROGRAMMING SERVICES                                                        -15.930500
# COATING, ENGRAVING, AND ALLIED SERVICES                                               17.422333
#
#                                                     ALT1_PCT   ALT2_PCT  \
# SICDESC
# FEDERAL AND FEDERALLY-SPONSORED CREDIT AGENCIES    24.310932  28.389455
# CONGLOMERATES                                       6.744420  30.067260
# FINANCE SERVICES                                    4.689786  12.762500
# BEVERAGES                                          17.127250  23.581750
# SECURITY BROKERS, DEALERS, & FLOTATION COMPANIES   95.665946  37.852610
# ...                                                      ...        ...
# DRAWING AND INSULATING OF NONFERROUS WIRE           9.351625  -8.204000
# PENS, PENCILS, AND OTHER ARTISTS' MATERIALS       106.724800   5.410600
# POWER, DISTRIBUTION, AND SPECIALTY TRANSFORMERS    34.927467  37.677267
# COMPUTER PROGRAMMING SERVICES                      29.395500  29.395500
# COATING, ENGRAVING, AND ALLIED SERVICES            24.574000  24.574000
#
#                                                     TDC1_PCT    TDC2_PCT  \
# SICDESC
# FEDERAL AND FEDERALLY-SPONSORED CREDIT AGENCIES    24.380182   30.606159
# CONGLOMERATES                                       6.961160   28.557780
# FINANCE SERVICES                                   11.553286   19.378179
# BEVERAGES                                          22.301667   23.886250
# SECURITY BROKERS, DEALERS, & FLOTATION COMPANIES   96.460220  100.540524
# ...                                                      ...         ...
# DRAWING AND INSULATING OF NONFERROUS WIRE           9.351625   -8.204000
# PENS, PENCILS, AND OTHER ARTISTS' MATERIALS       117.785000   92.452000
# POWER, DISTRIBUTION, AND SPECIALTY TRANSFORMERS    34.879667   34.879667
# COMPUTER PROGRAMMING SERVICES                      29.395500   29.395500
# COATING, ENGRAVING, AND ALLIED SERVICES            24.574000   24.574000
#
#                                                         EXECID      SPINDEX
# SICDESC
# FEDERAL AND FEDERALLY-SPONSORED CREDIT AGENCIES   39587.245902  4012.786885
# CONGLOMERATES                                     20736.196970  2740.909091
# FINANCE SERVICES                                  48845.617021  4010.000000
# BEVERAGES                                         37001.272727  3020.000000
# SECURITY BROKERS, DEALERS, & FLOTATION COMPANIES  36130.352531  4020.000000
# ...                                                        ...          ...
# DRAWING AND INSULATING OF NONFERROUS WIRE         36524.500000  2010.000000
# PENS, PENCILS, AND OTHER ARTISTS' MATERIALS       26983.600000  2520.000000
# POWER, DISTRIBUTION, AND SPECIALTY TRANSFORMERS   32043.600000  2010.000000
# COMPUTER PROGRAMMING SERVICES                     42553.333333  4510.000000
# COATING, ENGRAVING, AND ALLIED SERVICES           35473.000000  1510.000000
#
# [346 rows x 54 columns]

# %%
FinancialData=FinancialData.set_index(['Long-Term Debt – Total','SICDESC'])
FinancialData.head(1)
# Out:
#                                                                      GVKEY  \
# Long-Term Debt – Total SICDESC
# 622.2                  MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE   1004
#
#                                                                      YEAR  \
# Long-Term Debt – Total SICDESC
# 622.2                  MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE  2012
#
#                                                                     Industry Format  \
# Long-Term Debt – Total SICDESC
# 622.2                  MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE            INDL
#
#                                                                     TICKER  \
# Long-Term Debt – Total SICDESC
# 622.2                  MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE    AIR
#
#                                                                     Company Name  \
# Long-Term Debt – Total SICDESC
# 622.2                  MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE     AAR CORP
#
#                                                                     Currency  \
# Long-Term Debt – Total SICDESC
# 622.2                  MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE      USD
#
#                                                                      Assets and Liabilities Due in 2 year  \
# Long-Term Debt – Total SICDESC
# 622.2                  MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE                                   NaN
#
#                                                                      Assets – Total  \
# Long-Term Debt – Total SICDESC
# 622.2                  MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE          2136.9
#
#                                                                      Capital Surplus  \
# Long-Term Debt – Total SICDESC
# 622.2                  MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE            431.6
#
#                                                                      Debt – Due in One Year  \
# Long-Term Debt – Total SICDESC
# 622.2                  MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE                    86.4
#
#                                                                      ...  \
# Long-Term Debt – Total SICDESC                                       ...
# 622.2                  MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE  ...
#
#                                                                           CITY  \
# Long-Term Debt – Total SICDESC
# 622.2                  MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE  Wood Dale
#
#                                                                     STATE  \
# Long-Term Debt – Total SICDESC
# 622.2                  MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE    IL
#
#                                                                        ZIP  \
# Long-Term Debt – Total SICDESC
# 622.2                  MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE  60191
#
#                                                                              TELE  \
# Long-Term Debt – Total SICDESC
# 622.2                  MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE  630 227 2000
#
#                                                                                                              NAICSDESC  \
# Long-Term Debt – Total SICDESC
# 622.2                  MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE  Transportation Equipment and Supplies (except ...
#
#                                                                                  INDDESC  \
# Long-Term Debt – Total SICDESC
# 622.2                  MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE  Aerospace & Defense
#
#                                                                     SPCODE  \
# Long-Term Debt – Total SICDESC
# 622.2                  MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE     EX
#
#                                                                       NAICS  \
# Long-Term Debt – Total SICDESC
# 622.2                  MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE  423860
#
#                                                                      SPINDEX  \
# Long-Term Debt – Total SICDESC
# 622.2                  MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE   2010.0
#
#                                                                       SIC
# Long-Term Debt – Total SICDESC
# 622.2                  MACHINERY, EQUIPMENT, AND SUPPLIES-WHOLESALE  5080
#
# [1 rows x 80 columns]

# %% [markdown]
# 2.c) Using FirmAndExecutivesFinancialData, calculate the average "Long-Term Debt – Total" per Industry within STATE (5 pts)
# * NAICS or SIC represent industries. You can use either of the two.
# * Which Industry has the highest average "Long-Term Debt – Total" in North Carolina [NC]? (2.5 pts)
# * Which Industry has the highest average "Long-Term Debt – Total" in New York [NY]? (2.5 pts)

# %%
FinancialDataState=FinancialData.mean(level=['Long-Term Debt – Total','SICDESC']).reset_index()
FinancialDataState[FinancialDataState.STATE == "NC"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-239-543b35fe5370> in <module>
#       1 FinancialDataState=FinancialData.mean(level=['Long-Term Debt – Total','SICDESC']).reset_index()
# ----> 2 FinancialDataState[FinancialDataState.STATE == "NC"]
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'STATE'

# %%
FinancialDataState[FinancialDataState.STATE == "NY"].sort_values(by=['Long-Term Debt – Total'],ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-233-fabc1ced176f> in <module>
# ----> 1 FinancialDataState[FinancialDataState.STATE == "NY"].sort_values(by=['Long-Term Debt – Total'],ascending=False)
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'STATE'

# %% [markdown]
# 2.d) Using FirmAndExecutivesFinancialData, calculate the average  "Long-Term Debt – Total" per Industry within YEAR (5 pts)
# * NAICS or SIC represent industries. You can use either of the two.
# * Which Industry has the highest average  "Long-Term Debt – Total" in 2012? (2.5 pts)
# * Which Industry has the lowest average  "Long-Term Debt – Total" in 2015? (2.5 pts)

# %%
# write code here
FinancialDataState[FinancialDataState.YEAR == "2012"]
# Out:
# Empty DataFrame
# Columns: [Long-Term Debt – Total, SICDESC, GVKEY, YEAR, Assets and Liabilities Due in 2 year, Assets – Total, Capital Surplus, Debt – Due in One Year, exchg, CO_PER_ROL, SALARY, BONUS, NONEQuity_INCENT, PENSION_CHG, Other Compensation, Total Compensation - As Reported in SEC, Total Current Compensation (Salary + Bonus, ALT 1 Total Compensation (fair value of stock/optio, TOTAL_ALT2 -- Total Compensation - Stock Valued at time of, Estimated Payments in event of involuntary te, Estimated Payments in event of change in cont, Shares Owned, SHROWN_TOT_PCT, Shares Owned - Options Excluded, SHROWN_EXCL_OPTS_PCT, umber of Shares Acquired on Option Exercise, Value Realized on Option Exercise, Number of Shares Acquired on Vesting, Value Realized on Vesting, AGE, Options Granted, Grant Date Fair Value of Options Granted , STOCK_AWARDS_Fair Value, Unexercised Exercisable Options, Unexercised Exercisable Options.1, Estimated Value Of In-the-Money exercised, Estimated Value Of In-the-Money Unexercised, Restricted Stock Holdings, Restricted Stock Holdings Value, Equity Incentive Plan--Number of Unearned Share, Equity Incentive Plan - Value of Unearned, Present Value of Accumulated Pension Benefits, Total Payments Made From All Pension Plans, Executive Rank by Salary + Bonus, TDC1 Total Compensation, TDC2 Total compensation (Long-Term Incentive Payouts, and All Other Total), Salary Percent Change, Compensation Percent Change, Total Compensation (SEC total) Percent Change, ALT1_PCT, ALT2_PCT, TDC1_PCT, TDC2_PCT, EXECID, NAICS, SPINDEX, SIC]
# Index: []
#
# [0 rows x 57 columns]

# %%
# write code here
FinancialDataState[FinancialDataState.YEAR == "2015"]
# Out:
# Empty DataFrame
# Columns: [Long-Term Debt – Total, SICDESC, GVKEY, YEAR, Assets and Liabilities Due in 2 year, Assets – Total, Capital Surplus, Debt – Due in One Year, exchg, CO_PER_ROL, SALARY, BONUS, NONEQuity_INCENT, PENSION_CHG, Other Compensation, Total Compensation - As Reported in SEC, Total Current Compensation (Salary + Bonus, ALT 1 Total Compensation (fair value of stock/optio, TOTAL_ALT2 -- Total Compensation - Stock Valued at time of, Estimated Payments in event of involuntary te, Estimated Payments in event of change in cont, Shares Owned, SHROWN_TOT_PCT, Shares Owned - Options Excluded, SHROWN_EXCL_OPTS_PCT, umber of Shares Acquired on Option Exercise, Value Realized on Option Exercise, Number of Shares Acquired on Vesting, Value Realized on Vesting, AGE, Options Granted, Grant Date Fair Value of Options Granted , STOCK_AWARDS_Fair Value, Unexercised Exercisable Options, Unexercised Exercisable Options.1, Estimated Value Of In-the-Money exercised, Estimated Value Of In-the-Money Unexercised, Restricted Stock Holdings, Restricted Stock Holdings Value, Equity Incentive Plan--Number of Unearned Share, Equity Incentive Plan - Value of Unearned, Present Value of Accumulated Pension Benefits, Total Payments Made From All Pension Plans, Executive Rank by Salary + Bonus, TDC1 Total Compensation, TDC2 Total compensation (Long-Term Incentive Payouts, and All Other Total), Salary Percent Change, Compensation Percent Change, Total Compensation (SEC total) Percent Change, ALT1_PCT, ALT2_PCT, TDC1_PCT, TDC2_PCT, EXECID, NAICS, SPINDEX, SIC]
# Index: []
#
# [0 rows x 57 columns]

# %% [markdown]
# ***Question 3 (20 pts)***

# %% [markdown]
# 3.a) Create a pie plot that shows average "Long-Term Debt – Total" per GENDER (5 pts)

# %%
FinancialDataDebt=FinancialData.mean(level='Long-Term Debt – Total')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-205-64710405eba8> in <module>
# ----> 1 FinancialDataDebt=FinancialData.mean(level='Long-Term Debt – Total')
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11116         )
#   11117         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 11118             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11119
#   11120         # pandas\core\generic.py:10924: error: Cannot assign to a method
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10724
#   10725     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10726         return self._stat_function(
#   10727             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10728         )
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10708             axis = self._stat_axis_number
#   10709         if level is not None:
# > 10710             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
#   10711         return self._reduce(
#   10712             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/generic.py in _agg_by_level(self, name, axis, level, skipna, **kwargs)
#   10555         if axis is None:
#   10556             raise ValueError("Must specify 'axis' when aggregating by level.")
# > 10557         grouped = self.groupby(level=level, axis=axis, sort=False)
#   10558         if hasattr(grouped, name) and skipna:
#   10559             return getattr(grouped, name)(**kwargs)
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
#     562                 keys,
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     703             if isinstance(level, str):
#     704                 if obj._get_axis(axis).name != level:
# --> 705                     raise ValueError(
#     706                         f"level name {level} is not the name "
#     707                         f"of the {obj._get_axis_name(axis)}"
#
# ValueError: level name Long-Term Debt – Total is not the name of the index

# %%
# write code here
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

y=FinancialDataDebt.mean().GENDER()
plt.pie(y)
plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-204-7d9274ec2225> in <module>
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#       5
# ----> 6 y=FinancialDataDebt.mean().GENDER()
#       7 plt.pie(y)
#       8 plt.show
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'GENDER'

# %% [markdown]
# 3.b) Create a bar plot that shows average  "Long-Term Debt – Total" per STATE (5 pts)

# %%
# write code here
# %matplotlib inline

x=pd.factorize(FinancialDataDebt.mean().index)[0]
y=FinancialDataDebt.mean().STATE
plt.bar(x,y)
plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-203-9562eb869bf7> in <module>
#       3
#       4 x=pd.factorize(FinancialDataDebt.mean().index)[0]
# ----> 5 y=FinancialDataDebt.mean().STATE
#       6 plt.bar(x,y)
#       7 plt.show
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'STATE'

# %% [markdown]
# 3.c) Create a bar plot that shows average "Long-Term Debt – Total" per GENDER for the state of North Carolina [NC] (5 pts)

# %%
# write code here
GenAGG=FinancialData[(FinancialData.STATE == 'NC')]
b=sns.barplot(data=GenAGG, x='Long-Term Debt – Total', y='GENDER')

# %% [markdown]
# 3.c) Create a histogram of "Long-Term Debt – Total" (5 pts)

# %%
# write code here
# %matplotlib inline
FinancialData['Long-Term Debt – Total'].plot.hist(bins=2)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ***Question 4 (15 pts)***

# %% [markdown]
# 4.a) Return the top 3 companies in each STATE based on the average "Long-Term Debt – Total" (5 pts)
# * You can use a user-defined function following the lecture notes
# * You will need to first aggregate at the company level to account for the fact that a company appears multiple times due to the column YEAR.
# * The unique identifier of company in the dataset is GVKEY. You can also use TICKER or Company Name

# %%
# write code here
FinancialDataAGG=FinancialData.groupby(FinancialData['STATE'])

# %%
FinancialDataAGG['YEAR','Long-Term Debt – Total'].mean()
# Out:
# <ipython-input-187-ada06bc3ec43>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   FinancialDataAGG['YEAR','Long-Term Debt – Total'].mean()
#               YEAR  Long-Term Debt – Total
# STATE
# AL     2013.394330             1235.021412
# AR     2013.562857             4444.148291
# AZ     2013.462418             1375.699443
# BC     2013.521739              782.760957
# CA     2013.455459             2505.100510
# CO     2013.510672             1991.366700
# CT     2013.473523             2830.429625
# DC     2013.521930           603695.218149
# DE     2013.629630            26649.637302
# FL     2013.510176             1607.480871
# GA     2013.490482             2706.178778
# HI     2013.572917              576.031505
# IA     2013.546980             2825.682215
# ID     2013.425532             1323.049837
# IL     2013.490921             3043.117472
# IN     2013.511538             3455.857455
# KS     2013.581749             4910.797255
# KY     2013.534743             1438.962076
# LA     2013.492063             3469.841025
# MA     2013.483516             4158.488430
# MD     2013.455135             1362.139012
# ME     2013.397059              521.516985
# MI     2013.442529             3523.343661
# MN     2013.485813             2951.621026
# MO     2013.446449             1896.216745
# MS     2013.478102              299.661916
# MT     2013.615385              373.571769
# NC     2013.482159            11257.310930
# ND     2013.461538             1260.905585
# NE     2013.532751             8968.663860
# NH     2013.435294              153.173576
# NJ     2013.450641             2798.042530
# NM     2013.500000             1737.293250
# NV     2013.440964             3433.243111
# NY     2013.476293            11656.942128
# OH     2013.505641             2728.183224
# OK     2013.492505             2804.042604
# ON     2013.527778             6804.898236
# OR     2013.471963              780.316371
# PA     2013.477006             2758.210638
# PR     2013.509202             1276.795834
# QC     2013.476190              579.619048
# RI     2013.576271             4899.508008
# SC     2013.534188              894.122502
# SD     2013.653595              473.410758
# TN     2013.513889             2617.785071
# TX     2013.469150             2410.652156
# UT     2013.522472              735.249736
# VA     2013.487362            53089.595115
# WA     2013.446408             2239.221915
# WI     2013.503121             1231.821552
# WV     2013.481818              138.528855
# WY     2013.478261              598.366435

# %% [markdown]
# 4.b) Return the top 3 companies in each STATE led by MALE CEOs based on the average "Long-Term Debt – Total" (5 pts)
# * You can use a user-defined function following the lecture notes
# * GENDER contains the gender of CEOs
# * The unique identifier of company in the dataset is GVKEY. You can also use TICKER or Company Name

# %%
# write code here
FinancialDataAGG['GVKEY','Long-Term Debt – Total'].mean()
# Out:
# <ipython-input-190-b3b2e9d2cf85>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   FinancialDataAGG['GVKEY','Long-Term Debt – Total'].mean()
#                GVKEY  Long-Term Debt – Total
# STATE
# AL      48588.394330             1235.021412
# AR      50962.917143             4444.148291
# AZ      56100.227124             1375.699443
# BC      14563.000000              782.760957
# CA      73899.316811             2505.100510
# CO      76370.314625             1991.366700
# CT      51829.411358             2830.429625
# DC      40207.767544           603695.218149
# DE      12381.338624            26649.637302
# FL      71190.813599             1607.480871
# GA      46773.706218             2706.178778
# HI      15222.562500              576.031505
# IA      62641.154362             2825.682215
# ID      28099.368794             1323.049837
# IL      62437.131971             3043.117472
# IN      62985.426923             3455.857455
# KS      62804.988593             4910.797255
# KY      55141.069486             1438.962076
# LA      61380.952381             3469.841025
# MA      65469.127033             4158.488430
# MD      79163.400000             1362.139012
# ME     117677.117647              521.516985
# MI      37572.211686             3523.343661
# MN      41214.686156             2951.621026
# MO      45100.443067             1896.216745
# MS      18596.591241              299.661916
# MT      16832.000000              373.571769
# NC      43793.968893            11257.310930
# ND      44843.400000             1260.905585
# NE      64491.296943             8968.663860
# NH      63845.776471              153.173576
# NJ      72754.340385             2798.042530
# NM       8807.000000             1737.293250
# NV      74789.920482             3433.243111
# NY      58919.977155            11656.942128
# OH      22861.822051             2728.183224
# OK      50857.509636             2804.042604
# ON      86398.375000             6804.898236
# OR      41518.850467              780.316371
# PA      39557.862489             2758.210638
# PR      38899.601227             1276.795834
# QC       2337.000000              579.619048
# RI      21324.601695             4899.508008
# SC      56667.538462              894.122502
# SD      18296.183007              473.410758
# TN      47302.724359             2617.785071
# TX      61992.633371             2410.652156
# UT      42734.120787              735.249736
# VA      67612.606610            53089.595115
# WA      58371.637220             2239.221915
# WI      26736.077403             1231.821552
# WV      49387.981818              138.528855
# WY     180635.000000              598.366435

# %% [markdown]
# 4.c) Plot the average "Long-Term Debt – Total" per GENDER and YEAR (5 pts)
# * YEAR goes in the x axis, average "Long-Term Debt – Total" goes in the y axis, and GENDER is the color
# * You can use seaborn to create the plot

# %%
# write code here
FinancialDataAGG=FinancialData.groupby(FinancialData['YEAR'])

# %%
# write code here
import seaborn as sns 

# %matplotlib inline
FinancialDataAGG[['Long-Term Debt – Total']].plot.bar()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-206-25bc2f1061cd> in <module>
#       3
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 5 FinancialDataAGG[['Long-Term Debt – Total']].plot.bar()
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in attr(*args, **kwargs)
#     471                 return getattr(self.plot, name)(*args, **kwargs)
#     472
# --> 473             return self._groupby.apply(f)
#     474
#     475         return attr
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     892         with option_context("mode.chained_assignment", None):
#     893             try:
# --> 894                 result = self._python_apply_general(f, self._selected_obj)
#     895             except TypeError:
#     896                 # gh-20949
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data)
#     926             data after applying f
#     927         """
# --> 928         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#     929
#     930         return self._wrap_applied_output(
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     202         ):
#     203             try:
# --> 204                 result_values, mutated = splitter.fast_apply(f, sdata, group_keys)
#     205
#     206             except libreduction.InvalidApply as err:
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/groupby/ops.py in fast_apply(self, f, sdata, names)
#     999         # must return keys::list, values::list, mutated::bool
#    1000         starts, ends = lib.generate_slices(self.slabels, self.ngroups)
# -> 1001         return libreduction.apply_frame_axis0(sdata, f, names, starts, ends)
#    1002
#    1003     def _chop(self, sdata: DataFrame, slice_obj: slice) -> DataFrame:
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.apply_frame_axis0()
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in f(self)
#     469         def attr(*args, **kwargs):
#     470             def f(self):
# --> 471                 return getattr(self.plot, name)(*args, **kwargs)
#     472
#     473             return self._groupby.apply(f)
#
# /opt/conda/lib/python3.9/site-packages/pandas/plotting/_core.py in bar(self, x, y, **kwargs)
#    1111         other axis represents a measured value.
#    1112         """
# -> 1113         return self(kind="bar", x=x, y=y, **kwargs)
#    1114
#    1115     @Appender(
#
# /opt/conda/lib/python3.9/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# /opt/conda/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# /opt/conda/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     285         for ax in self.axes:
#     286             self._post_plot_logic_common(ax, self.data)
# --> 287             self._post_plot_logic(ax, self.data)
#     288
#     289     def _args_adjust(self):
#
# /opt/conda/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py in _post_plot_logic(self, ax, data)
#    1495         e_edge = self.ax_pos[-1] + 0.25 + self.bar_width + self.lim_offset
#    1496
# -> 1497         self._decorate_ticks(ax, name, str_index, s_edge, e_edge)
#    1498
#    1499     def _decorate_ticks(self, ax: "Axes", name, ticklabels, start_edge, end_edge):
#
# /opt/conda/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py in _decorate_ticks(self, ax, name, ticklabels, start_edge, end_edge)
#    1503             ax.set_xticks(np.array(self.xticks))
#    1504         else:
# -> 1505             ax.set_xticks(self.tick_pos)
#    1506             ax.set_xticklabels(ticklabels)
#    1507
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      71
#      72         def wrapper(self, *args, **kwargs):
# ---> 73             return get_method(self)(*args, **kwargs)
#      74
#      75         wrapper.__module__ = owner.__module__
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/axis.py in set_ticks(self, ticks, minor)
#    1843         else:
#    1844             self.set_major_locator(mticker.FixedLocator(ticks))
# -> 1845             return self.get_major_ticks(len(ticks))
#    1846
#    1847     def _get_tick_boxes_siblings(self, renderer):
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1352         while len(self.majorTicks) < numticks:
#    1353             # Update the new tick label properties from the old.
# -> 1354             tick = self._get_tick(major=True)
#    1355             self.majorTicks.append(tick)
#    1356             self._copy_tick_props(self.majorTicks[0], tick)
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2052         else:
#    2053             tick_kw = self._minor_tick_kw
# -> 2054         return XTick(self.axes, 0, major=major, **tick_kw)
#    2055
#    2056     def set_label_position(self, position):
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#     430             marker=self._tickmarkers[1],
#     431         )
# --> 432         self.gridline.set(
#     433             xdata=[0, 0], ydata=[0, 1],
#     434             transform=self.axes.get_xaxis_transform(which="grid"),
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/artist.py in set(self, **kwargs)
#    1152     def set(self, **kwargs):
#    1153         """A property batch setter.  Pass *kwargs* to set properties."""
# -> 1154         kwargs = cbook.normalize_kwargs(kwargs, self)
#    1155         move_color_to_start = False
#    1156         if "color" in kwargs:
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     404     @functools.wraps(func)
#     405     def wrapper(*inner_args, **inner_kwargs):
# --> 406         arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     407         if is_varargs and arguments.get(name):
#     408             warn_deprecated(
#
# /opt/conda/lib/python3.9/inspect.py in bind(self, *args, **kwargs)
#    3060         if the passed arguments can not be bound.
#    3061         """
# -> 3062         return self._bind(args, kwargs)
#    3063
#    3064     def bind_partial(self, /, *args, **kwargs):
#
# /opt/conda/lib/python3.9/inspect.py in _bind(self, args, kwargs, partial)
#    3003                                 arg=param.name)) from None
#    3004
# -> 3005                     arguments[param.name] = arg_val
#    3006
#    3007         # Now, we iterate through the remaining parameters to process
#
# KeyboardInterrupt:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7fd77e20e9d0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/conda/lib/python3.9/site-packages/matplotlib/pyplot.py in post_execute()
#     137             def post_execute():
#     138                 if matplotlib.is_interactive():
# --> 139                     draw_all()
#     140
#     141             # IPython >= 2
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     135         for manager in cls.get_all_fig_managers():
#     136             if force or manager.canvas.figure.stale:
# --> 137                 manager.canvas.draw_idle()
#     138
#     139
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2053         if not self._is_idle_drawing:
#    2054             with self._idle_draw_cntx():
# -> 2055                 self.draw(*args, **kwargs)
#    2056
#    2057     def get_width_height(self):
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     404              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     405               else nullcontext()):
# --> 406             self.figure.draw(self.renderer)
#     407             # A GUI class may be need to update a window using this draw, so
#     408             # don't forget to call the superclass.
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2764             return
#    2765
# -> 2766         artists = self._get_draw_artists(renderer)
#    2767
#    2768         try:
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/figure.py in _get_draw_artists(self, renderer)
#     241
#     242             for child in ax.get_children():
# --> 243                 if hasattr(child, 'apply_aspect'):
#     244                     locator = child.get_axes_locator()
#     245                     if locator:
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7fd77e215670> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/conda/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# /opt/conda/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# /opt/conda/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in _fetch_figure_metadata(fig)
#     229     if _is_transparent(fig.get_facecolor()):
#     230         # the background is transparent
# --> 231         ticksLight = _is_light([label.get_color()
#     232                                 for axes in fig.axes
#     233                                 for axis in (axes.xaxis, axes.yaxis)
#
# /opt/conda/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in <listcomp>(.0)
#     232                                 for axes in fig.axes
#     233                                 for axis in (axes.xaxis, axes.yaxis)
# --> 234                                 for label in axis.get_ticklabels()])
#     235         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     236             # there are one or more tick labels, all with the same lightness
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/axis.py in get_ticklabels(self, minor, which)
#    1225         if minor:
#    1226             return self.get_minorticklabels()
# -> 1227         return self.get_majorticklabels()
#    1228
#    1229     def get_majorticklines(self):
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1177     def get_majorticklabels(self):
#    1178         """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1179         ticks = self.get_major_ticks()
#    1180         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1181         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1352         while len(self.majorTicks) < numticks:
#    1353             # Update the new tick label properties from the old.
# -> 1354             tick = self._get_tick(major=True)
#    1355             self.majorTicks.append(tick)
#    1356             self._copy_tick_props(self.majorTicks[0], tick)
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2052         else:
#    2053             tick_kw = self._minor_tick_kw
# -> 2054         return XTick(self.axes, 0, major=major, **tick_kw)
#    2055
#    2056     def set_label_position(self, position):
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#     425             marker=self._tickmarkers[0],
#     426         )
# --> 427         self.tick2line.set(
#     428             xdata=[0], ydata=[1],
#     429             transform=self.axes.get_xaxis_transform(which="tick2"),
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/artist.py in set(self, **kwargs)
#    1152     def set(self, **kwargs):
#    1153         """A property batch setter.  Pass *kwargs* to set properties."""
# -> 1154         kwargs = cbook.normalize_kwargs(kwargs, self)
#    1155         move_color_to_start = False
#    1156         if "color" in kwargs:
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     404     @functools.wraps(func)
#     405     def wrapper(*inner_args, **inner_kwargs):
# --> 406         arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     407         if is_varargs and arguments.get(name):
#     408             warn_deprecated(
#
# /opt/conda/lib/python3.9/inspect.py in bind(self, *args, **kwargs)
#    3060         if the passed arguments can not be bound.
#    3061         """
# -> 3062         return self._bind(args, kwargs)
#    3063
#    3064     def bind_partial(self, /, *args, **kwargs):
#
# /opt/conda/lib/python3.9/inspect.py in _bind(self, args, kwargs, partial)
#    3030                 if (not partial and param.kind != _VAR_POSITIONAL and
#    3031                                                     param.default is _empty):
# -> 3032                     raise TypeError('missing a required argument: {arg!r}'. \
#    3033                                     format(arg=param_name)) from None
#    3034
#
# KeyboardInterrupt:

# %% [markdown]
# ***Question 5 (15 pts)***

# %% [markdown]
# Using **patsy** and **statsmodels**, fit two models that predict "Long-Term Debt – Total" (10 pts)
# For each model, choose a different combination of predictors. You can include categorical variables (e.g., State, Year, etc.), and/or numerical variables (e.g., Salary, Shares Owned, etc.)
# * Each model should have at least 5 predictors
#     * DO NOT USE ANY OF THE FOLLOWING VARIABLES: Net Income, Gross Profit, Long-Term Debt – Total, Assets – Total, and Debt – Due in One Year
#     * **IF I NOTICE THAT YOU LITERALLY COPIED THE PREDICTORS I USED IN THE PRACTICE EXAM, I WILL GIVE YOU ZERO ON THIS QUESTION.**
# * Each model is worth 5 pts
# * Select the best model based on the R-Squared coefficient (5 pts)
# * The best model is the one that has the highest R-Squared coefficient

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import patsy

# %%
# write code here
y,X=patsy.dmatrices('Long-Term Debt – Total ~ SALARY + BONUS + Other Compensation + Total Compensation - As Reported in SEC',FinancialData)
X
# Out:
# ---------------------------------------------------------------------------
# PatsyError                                Traceback (most recent call last)
# <ipython-input-176-8252aaf38fa6> in <module>
# ----> 1 y,X=patsy.dmatrices('Long-Term Debt – Total ~ SALARY + BONUS + Other Compensation + Total Compensation - As Reported in SEC',FinancialData)
#       2 X
#
# /opt/conda/lib/python3.9/site-packages/patsy/highlevel.py in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     307     """
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
#     310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#
# /opt/conda/lib/python3.9/site-packages/patsy/highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     162     def data_iter_maker():
#     163         return iter([data])
# --> 164     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
#     165                                       NA_action)
#     166     if design_infos is not None:
#
# /opt/conda/lib/python3.9/site-packages/patsy/highlevel.py in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      60                 "ascii-only, or else upgrade to Python 3.")
#      61     if isinstance(formula_like, str):
# ---> 62         formula_like = ModelDesc.from_formula(formula_like)
#      63         # fallthrough
#      64     if isinstance(formula_like, ModelDesc):
#
# /opt/conda/lib/python3.9/site-packages/patsy/desc.py in from_formula(cls, tree_or_string)
#     162             tree = tree_or_string
#     163         else:
# --> 164             tree = parse_formula(tree_or_string)
#     165         value = Evaluator().eval(tree, require_evalexpr=False)
#     166         assert isinstance(value, cls)
#
# /opt/conda/lib/python3.9/site-packages/patsy/parse_formula.py in parse_formula(code, extra_operators)
#     144     operators = _default_ops + extra_operators
#     145     operator_strings = [op.token_type for op in operators]
# --> 146     tree = infix_parse(_tokenize_formula(code, operator_strings),
#     147                        operators,
#     148                        _atomic_token_types)
#
# /opt/conda/lib/python3.9/site-packages/patsy/infix_parser.py in infix_parse(tokens, operators, atomic_types, trace)
#     208
#     209     want_noun = True
# --> 210     for token in token_source:
#     211         if c.trace:
#     212             print("Reading next token (want_noun=%r)" % (want_noun,))
#
# /opt/conda/lib/python3.9/site-packages/patsy/parse_formula.py in _tokenize_formula(code, operator_strings)
#      92         else:
#      93             it.push_back((pytype, token_string, origin))
# ---> 94             yield _read_python_expr(it, end_tokens)
#      95
#      96 def test__tokenize_formula():
#
# /opt/conda/lib/python3.9/site-packages/patsy/parse_formula.py in _read_python_expr(it, end_tokens)
#      42     origins = []
#      43     bracket_level = 0
# ---> 44     for pytype, token_string, origin in it:
#      45         assert bracket_level >= 0
#      46         if bracket_level == 0 and token_string in end_tokens:
#
# /opt/conda/lib/python3.9/site-packages/patsy/util.py in next(self)
#     347         else:
#     348             # May raise StopIteration
# --> 349             return six.advance_iterator(self._it)
#     350     __next__ = next
#     351
#
# /opt/conda/lib/python3.9/site-packages/patsy/tokens.py in python_tokenize(code)
#      38                 continue
#      39             if pytype == tokenize.ERRORTOKEN:
# ---> 40                 raise PatsyError("error tokenizing input "
#      41                                  "(maybe an unclosed string?)",
#      42                                  origin)
#
# PatsyError: error tokenizing input (maybe an unclosed string?)
#     Long-Term Debt – Total ~ SALARY + BONUS + Other Compensation + Total Compensation - As Reported in SEC
#                   ^

# %%
y,X=patsy.dmatrices('Long-Term Debt – Total + STATE + GENDER + CITY + EXEC_FNAME',FinancialData)
X
# Out:
# ---------------------------------------------------------------------------
# PatsyError                                Traceback (most recent call last)
# <ipython-input-178-d1f1e11d2ac1> in <module>
# ----> 1 y,X=patsy.dmatrices('Long-Term Debt – Total + STATE + GENDER + CITY + EXEC_FNAME',FinancialData)
#       2 X
#
# /opt/conda/lib/python3.9/site-packages/patsy/highlevel.py in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     307     """
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
#     310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#
# /opt/conda/lib/python3.9/site-packages/patsy/highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     162     def data_iter_maker():
#     163         return iter([data])
# --> 164     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
#     165                                       NA_action)
#     166     if design_infos is not None:
#
# /opt/conda/lib/python3.9/site-packages/patsy/highlevel.py in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      60                 "ascii-only, or else upgrade to Python 3.")
#      61     if isinstance(formula_like, str):
# ---> 62         formula_like = ModelDesc.from_formula(formula_like)
#      63         # fallthrough
#      64     if isinstance(formula_like, ModelDesc):
#
# /opt/conda/lib/python3.9/site-packages/patsy/desc.py in from_formula(cls, tree_or_string)
#     162             tree = tree_or_string
#     163         else:
# --> 164             tree = parse_formula(tree_or_string)
#     165         value = Evaluator().eval(tree, require_evalexpr=False)
#     166         assert isinstance(value, cls)
#
# /opt/conda/lib/python3.9/site-packages/patsy/parse_formula.py in parse_formula(code, extra_operators)
#     144     operators = _default_ops + extra_operators
#     145     operator_strings = [op.token_type for op in operators]
# --> 146     tree = infix_parse(_tokenize_formula(code, operator_strings),
#     147                        operators,
#     148                        _atomic_token_types)
#
# /opt/conda/lib/python3.9/site-packages/patsy/infix_parser.py in infix_parse(tokens, operators, atomic_types, trace)
#     208
#     209     want_noun = True
# --> 210     for token in token_source:
#     211         if c.trace:
#     212             print("Reading next token (want_noun=%r)" % (want_noun,))
#
# /opt/conda/lib/python3.9/site-packages/patsy/parse_formula.py in _tokenize_formula(code, operator_strings)
#      92         else:
#      93             it.push_back((pytype, token_string, origin))
# ---> 94             yield _read_python_expr(it, end_tokens)
#      95
#      96 def test__tokenize_formula():
#
# /opt/conda/lib/python3.9/site-packages/patsy/parse_formula.py in _read_python_expr(it, end_tokens)
#      42     origins = []
#      43     bracket_level = 0
# ---> 44     for pytype, token_string, origin in it:
#      45         assert bracket_level >= 0
#      46         if bracket_level == 0 and token_string in end_tokens:
#
# /opt/conda/lib/python3.9/site-packages/patsy/util.py in next(self)
#     347         else:
#     348             # May raise StopIteration
# --> 349             return six.advance_iterator(self._it)
#     350     __next__ = next
#     351
#
# /opt/conda/lib/python3.9/site-packages/patsy/tokens.py in python_tokenize(code)
#      38                 continue
#      39             if pytype == tokenize.ERRORTOKEN:
# ---> 40                 raise PatsyError("error tokenizing input "
#      41                                  "(maybe an unclosed string?)",
#      42                                  origin)
#
# PatsyError: error tokenizing input (maybe an unclosed string?)
#     Long-Term Debt – Total + STATE + GENDER + CITY + EXEC_FNAME
#                   ^

# %% [markdown]
# ^ I do not understand the error here as it thinks I have an unclosed string for both of the cells
